# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
data=pd.read_csv('bluebook-for-bulldozers/TrainAndValid.csv', low_memory=False, parse_dates=['saledate'])

# %%
data.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade
# 0  1139246    66000.0     999089     3157         121           3.0      2004  \
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate  ... Undercarriage_Pad_Width
# 0                      68.0       Low 2006-11-16  ...                     NaN  \
# 1                    4640.0       Low 2004-03-26  ...                     NaN
# 2                    2838.0      High 2004-02-26  ...                     NaN
# 3                    3486.0      High 2011-05-19  ...                     NaN
# 4                     722.0    Medium 2009-07-23  ...                     NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  datetime64[ns]
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
# ...

# %%
plt.scatter(data['saledate'][:1000],data['SalePrice'][:1000]);

# %%
data.sort_values(by=['saledate'], inplace=True)

# %%
data.head()
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID
# 205615  1646770     9500.0    1126363     8434         132          18.0  \
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
# 212552  1671174    16000.0    1327630     8591         132          99.0
# 62755   1329056    22000.0    1336053     4089         132          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand   saledate  ...
# 205615      1974                       NaN       NaN 1989-01-17  ...  \
# 274835      1980                       NaN       NaN 1989-01-31  ...
# 141296      1978                       NaN       NaN 1989-01-31  ...
# 212552      1980                       NaN       NaN 1989-01-31  ...
# 62755       1984                       NaN       NaN 1989-01-31  ...
#
#        Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer
# ...

# %%
data_temp=data.copy()

# %%
data_temp['SaleYear']= data_temp.saledate.dt.year
data_temp['SaleMonth']= data_temp.saledate.dt.month
data_temp['SaleDay']= data_temp.saledate.dt.day
data_temp['SaleDayOfWeek']= data_temp.saledate.dt.dayofweek
data_temp['SaleDayOfYear']= data_temp.saledate.dt.dayofyear

# %%
data_temp.head().T
# Out:
#                                                                      205615
# SalesID                                                             1646770  \
# SalePrice                                                            9500.0
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                           18.0
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                1989-01-17 00:00:00
# fiModelDesc                                                            TD20
# ...

# %%
data_temp.drop('saledate',axis=1,inplace= True)

# %%
data_temp.head().T
# Out:
#                                                                      205615
# SalesID                                                             1646770  \
# SalePrice                                                            9500.0
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                           18.0
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# fiModelDesc                                                            TD20
# fiBaseModel                                                            TD20
# ...

# %%
data_temp.state.value_counts().head().plot(kind='bar', title='Top Five States with Bulldozer Sales');

# %%
for label, content in data_temp.items():
    if pd.api.types.is_string_dtype(content):
        data_temp[label]=content.astype('category').cat.as_ordered()

# %%
for label, content in data_temp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            data_temp[label+"_is_missing"] = pd.isnull(content)
            data_temp[label]= content.fillna(content.median())

# %%
data_temp.auctioneerID_is_missing.value_counts()
# Out:
# auctioneerID_is_missing
# False    392562
# True      20136
# Name: count, dtype: int64

# %%
data_temp.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                     0
# YearMade                         0
# MachineHoursCurrentMeter         0
# UsageBand                   339028
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# Turbocharged                331602
# ...

# %%
data_temp.head().T
# Out:
#                                                                      205615  \
# SalesID                                                             1646770
# SalePrice                                                              9500
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                             18
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                  0
# UsageBand                                                               NaN
# fiModelDesc                                                            TD20
# fiBaseModel                                                            TD20
# ...

# %%
for label, content in data_temp.items():
    if not pd.api.types.is_numeric_dtype(content):
        data_temp[label+"_is_missing"] = pd.isnull(content)
        data_temp[label]=pd.Categorical(content).codes +1 #pandas makes missing value -1, so we want them to be 0

# %%
data_temp.head().T
# Out:
#                              205615     274835     141296     212552  \
# SalesID                   1646770.0  1821514.0  1505138.0  1671174.0
# SalePrice                    9500.0    14000.0    50000.0    16000.0
# MachineID                 1126363.0  1194089.0  1473654.0  1327630.0
# ModelID                      8434.0    10150.0     4139.0     8591.0
# datasource                    132.0      132.0      132.0      132.0
# auctioneerID                   18.0       99.0       99.0       99.0
# YearMade                     1974.0     1980.0     1978.0     1980.0
# MachineHoursCurrentMeter        0.0        0.0        0.0        0.0
# UsageBand                       0.0        0.0        0.0        0.0
# fiModelDesc                  4593.0     1820.0     2348.0     1819.0
# fiBaseModel                  1744.0      559.0      713.0      558.0
# fiSecondaryDesc                 0.0        0.0       59.0        0.0
# fiModelSeries                   0.0        0.0        0.0        0.0
# ...

# %%
#Time series 
data_train=data_temp[data_temp.SaleYear!=2012]
data_val=data_temp[data_temp.SaleYear==2012]

# %%
X_train, y_train = data_train.drop('SalePrice', axis=1), data_train.SalePrice
X_val, y_val = data_val.drop('SalePrice', axis=1), data_val.SalePrice

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_log_error, mean_absolute_error

# %%
model = RandomForestRegressor(n_jobs=-1, random_state=42, max_samples=10000)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_samples=10000, n_jobs=-1, random_state=42)

# %%
#Evaluation function
def evaluate(y_true, y_pred):
    loss = mean_squared_log_error(y_true, y_pred)
    return np.sqrt(loss)
def show_scores(model):
    train_preds = model.predict(X_train)
    val_pred = model.predict(X_val)
    scores = {"Training MAE": mean_absolute_error(y_train, train_preds),
              "Val MAE": mean_absolute_error(y_val, val_pred),
              "Training RSMLE": evaluate(y_train, train_preds),
              "Val RSMLE": evaluate(y_val, val_pred)}
    return scores

# %%
show_scores(model)
# Out:
# {'Training MAE': 5561.2988092240585,
#  'Val MAE': 7177.26365505919,
#  'Training RSMLE': 0.257745378256977,
#  'Val RSMLE': 0.29362638671089003}

# %%
from sklearn.model_selection import RandomizedSearchCV

rf_grid = {"n_estimators" : np.arange(10, 100, 10),
           "max_depth" : [None, 3, 5, 10],
           "min_samples_split" : np.arange(2, 20, 2),
           "min_samples_leaf" : np.arange(1, 20, 2),
           "max_features" : [0.5, 1, "sqrt", "auto"],
           "max_samples" :[10000]
            }

rs_model = RandomizedSearchCV(RandomForestRegressor(n_jobs=-1, random_state=42), 
                              param_distributions=rf_grid, 
                              n_iter=30,
                              cv=5, verbose=True)

rs_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# c:\Users\gbeng\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# c:\Users\gbeng\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# ...

# %%
rs_model.best_params_
# Out:
# {'n_estimators': 80,
#  'min_samples_split': 18,
#  'min_samples_leaf': 9,
#  'max_samples': 10000,
#  'max_features': 'auto',
#  'max_depth': None}

# %%
show_scores(rs_model)
# Out:
# {'Training MAE': 6057.146464449309,
#  'Val MAE': 7643.762427103387,
#  'Training RSMLE': 0.2755075595668634,
#  'Val RSMLE': 0.3057746764604973}

# %%
best_model =  RandomForestRegressor(n_estimators=80, min_samples_split=18, min_samples_leaf=9, max_samples=10000, max_features="auto", max_depth=None)

# %%
best_model.fit(X_train, y_train)
# Out:
# c:\Users\gbeng\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# RandomForestRegressor(max_features='auto', max_samples=10000,
#                       min_samples_leaf=9, min_samples_split=18,
#                       n_estimators=80)

# %%
show_scores(best_model) #more search will help better the score
# Out:
# {'Training MAE': 6056.769092312154,
#  'Val MAE': 7648.5008556014345,
#  'Training RSMLE': 0.27580750821088235,
#  'Val RSMLE': 0.3077534381309389}

# %%
X_train.head()
# Out:
#         SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade
# 205615  1646770    1126363     8434         132          18.0      1974  \
# 274835  1821514    1194089    10150         132          99.0      1980
# 141296  1505138    1473654     4139         132          99.0      1978
# 212552  1671174    1327630     8591         132          99.0      1980
# 62755   1329056    1336053     4089         132          99.0      1984
#
#         MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...
# 205615                       0.0          0         4593         1744  ...  \
# 274835                       0.0          0         1820          559  ...
# 141296                       0.0          0         2348          713  ...
# 212552                       0.0          0         1819          558  ...
# 62755                        0.0          0         2119          683  ...
#
#         Undercarriage_Pad_Width_is_missing  Stick_Length_is_missing
# ...

# %%
test_data = pd.read_csv('bluebook-for-bulldozers/Test.csv', low_memory=False, parse_dates=['saledate'])

# %%
def preprocess_data(df):
    df['SaleYear']= df.saledate.dt.year
    df['SaleMonth']= df.saledate.dt.month
    df['SaleDay']= df.saledate.dt.day
    df['SaleDayOfWeek']= df.saledate.dt.dayofweek
    df['SaleDayOfYear']= df.saledate.dt.dayofyear

    df.drop("saledate", axis=1, inplace=True)
    
    #Fill the numeric rows with median
    for label, content in df.items():
        if pd.api.types.is_string_dtype(content):
            df[label]=content.astype('category').cat.as_ordered()
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                df[label+"_is_missing"] = pd.isnull(content)
                df[label]= content.fillna(content.median())

    #Fill categorical missing data and turn categories into numeric
        if not pd.api.types.is_numeric_dtype(content):
            df[label+"_is_missing"] = pd.isnull(content)
            df[label]=pd.Categorical(content).codes +1 

    return df

# %%
preprocess_data(test_data)
# Out:
#        SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade
# 0      1227829    1006309     3168         121             3      1999  \
# 1      1227844    1022817     7271         121             3      1000
# 2      1227847    1031560    22805         121             3      2004
# 3      1227848      56204     1269         121             3      2006
# 4      1227863    1053887    22312         121             3      2005
# ...        ...        ...      ...         ...           ...       ...
# 12452  6643171    2558317    21450         149             2      2008
# 12453  6643173    2558332    21434         149             2      2005
# 12454  6643184    2558342    21437         149             2      1000
# 12455  6643186    2558343    21437         149             2      2006
# 12456  6643196    2558346    21446         149             2      2008
#
#        MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...
# ...

# %%
set(X_train.columns) - set(test_data.columns)
# Out:
# {'auctioneerID_is_missing'}

# %%
col = [col for col in X_train.columns]
index = col.index('auctioneerID_is_missing')

# %%
test_data.insert(index, 'auctioneerID_is_missing', False)

# %%
X_train.columns == test_data.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
X_train.columns
# Out:
# Index(['SalesID', 'MachineID', 'ModelID', 'datasource', 'auctioneerID',
#        'YearMade', 'MachineHoursCurrentMeter', 'UsageBand', 'fiModelDesc',
#        'fiBaseModel',
#        ...
#        'Undercarriage_Pad_Width_is_missing', 'Stick_Length_is_missing',
#        'Thumb_is_missing', 'Pattern_Changer_is_missing',
#        'Grouser_Type_is_missing', 'Backhoe_Mounting_is_missing',
#        'Blade_Type_is_missing', 'Travel_Controls_is_missing',
#        'Differential_Type_is_missing', 'Steering_Controls_is_missing'],
#       dtype='object', length=102)

# %%
test_data.columns
# Out:
# Index(['SalesID', 'MachineID', 'ModelID', 'datasource', 'auctioneerID',
#        'YearMade', 'MachineHoursCurrentMeter', 'UsageBand', 'fiModelDesc',
#        'fiBaseModel',
#        ...
#        'Undercarriage_Pad_Width_is_missing', 'Stick_Length_is_missing',
#        'Thumb_is_missing', 'Pattern_Changer_is_missing',
#        'Grouser_Type_is_missing', 'Backhoe_Mounting_is_missing',
#        'Blade_Type_is_missing', 'Travel_Controls_is_missing',
#        'Differential_Type_is_missing', 'Steering_Controls_is_missing'],
#       dtype='object', length=102)

# %%
test_data.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade
# 0  1227829    1006309     3168         121             3      1999  \
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...
# 0                    3688.0          2          499          180  ...  \
# 1                   28555.0          1          831          292  ...
# 2                    6038.0          3         1177          404  ...
# 3                    8940.0          1          287          113  ...
# 4                    2286.0          2          566          196  ...
#
#    Undercarriage_Pad_Width_is_missing  Stick_Length_is_missing
# 0                                True                     True  \
# ...

# %%
test_pred = best_model.predict(test_data)

# %%
final_submission = pd.DataFrame()
final_submission["SalesID"] = test_data["SalesID"]
final_submission["SalesPrice"] = test_pred

# %%
final_submission
final_submission.to_csv('bluebook-for-bulldozers/Test_prediction.csv')

# %%
best_model.feature_importances_
# Out:
# array([4.27209213e-02, 1.28376439e-02, 2.65294336e-02, 2.96676551e-04,
#        1.83328303e-03, 2.79131720e-01, 2.20334957e-03, 3.86743987e-04,
#        2.01595558e-02, 5.43299733e-02, 5.69997249e-02, 2.95659878e-03,
#        4.47901373e-03, 2.43762208e-01, 3.33279641e-02, 4.03415075e-03,
#        1.54169547e-03, 2.24479318e-03, 1.38185973e-03, 3.51365825e-02,
#        3.66535817e-04, 7.69025252e-04, 7.76802446e-04, 2.22118079e-04,
#        4.58562018e-04, 4.69626559e-06, 4.22290325e-04, 1.83297374e-02,
#        3.83993349e-03, 5.94560306e-04, 3.21629559e-03, 1.30450419e-03,
#        4.14336254e-03, 2.51602722e-03, 1.35926361e-03, 3.40056964e-03,
#        7.42880361e-04, 1.74321309e-02, 3.08837753e-04, 1.09396667e-03,
#        1.01160315e-04, 6.97743640e-04, 7.74599775e-04, 5.27466088e-04,
#        2.59059152e-04, 2.08437968e-04, 5.81591920e-05, 1.19783646e-03,
#        5.81479484e-04, 1.79037257e-04, 1.14798111e-04, 6.42468242e-02,
# ...

# %%
def plot_features(columns, importances, n=20):
    df = (pd.DataFrame({"features":columns, 
                        "feature_importances":importances}).sort_values("feature_importances", ascending=  False).reset_index(drop=True))
    
    fig, ax = plt.subplots()
    ax.barh(df["features"][:n], df["feature_importances"][:20])
    ax.set_ylabel("Features")
    ax.set_xlabel("Feature importance")
    ax.invert_yaxis()

# %%
plot_features(X_train.columns, best_model.feature_importances_)
